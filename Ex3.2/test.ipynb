# %%
import torch
import numpy as np
from utils import model,validation
import matplotlib.pyplot as plt

# %%
y = torch.load("/Users/dual/Documents/projects/ReviewArticle/Poisson_Ldomain/results/PINN_t1/y.pt")

# %%
print(validation.y_L2)
# Out:
# 0.5996840795587178

# %%
vy,yp,ygt = validation.validate(y)

# %%
vy
# Out:
# 0.046710154673495194

# %%
yp.shape
# Out:
# (12352, 1)

# %%
ygt.shape
# Out:
# (12352, 1)

# %%
plt.scatter(validation.plot_val_x1,validation.plot_val_x2,c=np.abs(yp-ygt.reshape(-1,1)))
plt.colorbar()

# %%
np.mean(np.abs(yp-ygt.reshape(-1,1)))
# Out:
# 0.020366278387046667

# %%
u_net = torch.load("/Users/dual/Documents/projects/ReviewArticle/Poisson_Ldomain/results/VPINN_t1/u_net.pt")
ub = torch.load("/Users/dual/Documents/projects/ReviewArticle/Poisson_Ldomain/results/VPINN_t1/ub.pt")

# %%
def u(qp):
    return u_net(qp,ub)

# %%
vy,yp,ygt = validation.validate_vpinn(u)

# %%
vy
# Out:
# 0.058947299251439

# %%
plt.scatter(validation.plot_val_x1,validation.plot_val_x2,c=np.abs(yp-ygt.reshape(-1,1)))
plt.colorbar()
