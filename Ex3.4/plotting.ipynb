# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl

# %%
num = [0.051, 0.049,0.0505,0.053,0.051,0.052,0.054,0.052,0.048]

# %%
np.std(num)
# Out:
# 0.0017638342073763927

# %%
with open("results/losshist.pkl",'rb') as pfile:
    hist = pkl.load(pfile)

# %%
plt.plot(hist,label='loss')
plt.yscale('log')
plt.legend()
